# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# ADD YOUR GITHUB USERNAME AND PASSWORD WHERE MENTIONED (REMOVE THE PARENTHESIS ALSO)
# !git clone https://AtrikDas:#######@github.com/fellowship/Implant-Identification.git
# Out:
# Cloning into 'Implant-Identification'...
# remote: Enumerating objects: 403, done.
# remote: Counting objects: 100% (111/111), done.
# remote: Compressing objects: 100% (85/85), done.
# remote: Total 403 (delta 57), reused 38 (delta 19), pack-reused 292
# Receiving objects: 100% (403/403), 114.67 MiB | 25.44 MiB/s, done.
# Resolving deltas: 100% (117/117), done.
# Checking out files: 100% (103/103), done.

# %%
import argparse
import os
import torch
import numpy as np
import cv2
import shutil, sys

# %%
# Create important folders for the algorithms to function properly
# %cd "/content/Implant-Identification/Data Denoising"
# !mkdir models
# !mkdir input
# !mkdir results
# Out:
# /content/Implant-Identification/Data Denoising

# %%
# Copy the dataset you want to denoise inside the 'input' folder
# %cd "/content/drive/MyDrive/StyleGAN2_Datasets/Adversarial_Dataset/"
# %cp -av "1_fake/" "/content/Implant-Identification/Data Denoising/input"
# Out:
# /content/drive/MyDrive/StyleGAN2_Datasets/Adversarial_Dataset
# '1_fake/' -> '/content/Implant-Identification/Data Denoising/input/1_fake'
# '1_fake/img_fake_8.png' -> '/content/Implant-Identification/Data Denoising/input/1_fake/img_fake_8.png'
# '1_fake/img_fake_1.png' -> '/content/Implant-Identification/Data Denoising/input/1_fake/img_fake_1.png'
# '1_fake/img_fake_12.png' -> '/content/Implant-Identification/Data Denoising/input/1_fake/img_fake_12.png'
# '1_fake/img_fake_22.png' -> '/content/Implant-Identification/Data Denoising/input/1_fake/img_fake_22.png'
# '1_fake/img_fake_24.png' -> '/content/Implant-Identification/Data Denoising/input/1_fake/img_fake_24.png'
# '1_fake/img_fake_16.png' -> '/content/Implant-Identification/Data Denoising/input/1_fake/img_fake_16.png'
# '1_fake/img_fake_27.png' -> '/content/Implant-Identification/Data Denoising/input/1_fake/img_fake_27.png'
# '1_fake/img_fake_2.png' -> '/content/Implant-Identification/Data Denoising/input/1_fake/img_fake_2.png'
# ...

# %%
# Copy the KPN model from our drive to the 'models' folder
# %cd "/content/drive/MyDrive/Cohort May 2021/models/"
# %cp -av "KPN_single_image_epoch200_bs16_mu0_sigma30.pth" "/content/Implant-Identification/Data Denoising/models"
# Out:
# /content/drive/.shortcut-targets-by-id/15UpSt3B9eY-Ibmsdh_kYnGwJnW8lKB4I/Cohort May 2021/models
# 'KPN_single_image_epoch200_bs16_mu0_sigma30.pth' -> '/content/Implant-Identification/Data Denoising/models/KPN_single_image_epoch200_bs16_mu0_sigma30.pth'

# %%
# %cd /content/Implant-Identification/Data Denoising
# Out:
# /content/Implant-Identification/Data Denoising

# %%
# Reformat all images into 256x256 and png. MAY HAVE TO CHANGE THE PATH IN REFORMAT.PY
# !python reformat.py

# %%
# Run the KPN denoising algorithm
# !python validation.py
# Out:
# Namespace(add_noise=False, angle_aug=False, baseroot='./input', blind_est=True, burst_length=1, channel_att=False, color=True, core_bias=False, crop=False, crop_size=512, geometry_aug=False, init_gain=0.02, init_type='xavier', kernel_size=[5], load_name='./models/KPN_single_image_epoch200_bs16_mu0_sigma30.pth', mu=0, num_workers=1, save_name='./results', scale_max=1, scale_min=1, sep_conv=False, sigma=30, spatial_att=False, test_batch_size=1, upMode='bilinear')
# Generator is loaded!
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3613: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
#   "See the documentation of nn.Upsample for details.".format(mode)
# The 0-th iteration
# The 1-th iteration
# The 2-th iteration
# The 3-th iteration
# The 4-th iteration
# The 5-th iteration
# The 6-th iteration
# ...

# %%
# Copy the denoised images in 'results' folder to your destination folder on the drive
# !cp -r "/content/Implant-Identification/Data Denoising/results" "/content/drive/MyDrive/StyleGAN2_Datasets/Gaussian_Denoised_Dataset/1_fake"

# %%
# Zip and download the 'results' folder
# !zip -r "/content/Implant-Identification/Data Denoising/results_adversarial_denoised_fake.zip" "/content/Implant-Identification/Data Denoising/results"
# from google.colab import files
# files.download("/content/Implant-Identification/Data Denoising/results.zip")
# Out:
#   adding: content/Implant-Identification/Data Denoising/results/ (stored 0%)
#   adding: content/Implant-Identification/Data Denoising/results/img_fake_821.png (deflated 3%)
#   adding: content/Implant-Identification/Data Denoising/results/img_fake_701.png (deflated 3%)
#   adding: content/Implant-Identification/Data Denoising/results/img_fake_476.png (deflated 2%)
#   adding: content/Implant-Identification/Data Denoising/results/img_fake_361.png (deflated 3%)
#   adding: content/Implant-Identification/Data Denoising/results/img_fake_175.png (deflated 4%)
#   adding: content/Implant-Identification/Data Denoising/results/img_fake_49.png (deflated 4%)
#   adding: content/Implant-Identification/Data Denoising/results/img_fake_21.png (deflated 4%)
#   adding: content/Implant-Identification/Data Denoising/results/img_fake_526.png (deflated 2%)
#   adding: content/Implant-Identification/Data Denoising/results/img_fake_443.png (deflated 3%)
# ...
