# %%
# %tensorflow_version 1.x
import tensorflow as tf
# Out:
# TensorFlow 1.x selected.

# %%
# !git clone https://github.com/NVlabs/stylegan2.git
# Out:
# Cloning into 'stylegan2'...
# remote: Enumerating objects: 131, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 131 (delta 0), reused 1 (delta 0), pack-reused 127
# Receiving objects: 100% (131/131), 593.76 KiB | 5.76 MiB/s, done.
# Resolving deltas: 100% (58/58), done.

# %%
cd stylegan2
# Out:
# /content/stylegan2

# %%
# !python run_generator.py generate-images --network=gdrive:networks/stylegan2-ffhq-config-f.pkl --seeds=6200-6640 --truncation-psi=0.5
# Out:
# Local submit - run_dir: results/00001-generate-images
# dnnlib: Running run_generator.generate_images() on localhost...
# Loading networks from "gdrive:networks/stylegan2-ffhq-config-f.pkl"...
# Setting up TensorFlow plugin "fused_bias_act.cu": Preprocessing... Loading... Done.
# Setting up TensorFlow plugin "upfirdn_2d.cu": Preprocessing... Loading... Done.
# Generating image for seed 6200 (0/441) ...
# Generating image for seed 6201 (1/441) ...
# Generating image for seed 6202 (2/441) ...
# Generating image for seed 6203 (3/441) ...
# Generating image for seed 6204 (4/441) ...
# Generating image for seed 6205 (5/441) ...
# Generating image for seed 6206 (6/441) ...
# Generating image for seed 6207 (7/441) ...
# Generating image for seed 6208 (8/441) ...
# Generating image for seed 6209 (9/441) ...
# Generating image for seed 6210 (10/441) ...
# Generating image for seed 6211 (11/441) ...
# Generating image for seed 6212 (12/441) ...
# Generating image for seed 6213 (13/441) ...
# ...

# %%
# !python run_generator.py generate-images --network=gdrive:networks/stylegan2-cat-config-f.pkl --seeds=6200-6640 --truncation-psi=0.5
# Out:
# Local submit - run_dir: results/00002-generate-images
# dnnlib: Running run_generator.generate_images() on localhost...
# Loading networks from "gdrive:networks/stylegan2-cat-config-f.pkl"...
# ...
# Setting up TensorFlow plugin "fused_bias_act.cu": Preprocessing... Loading... Done.
# Setting up TensorFlow plugin "upfirdn_2d.cu": Preprocessing... Loading... Done.
# Generating image for seed 6200 (0/441) ...
# Generating image for seed 6201 (1/441) ...
# Generating image for seed 6202 (2/441) ...
# Generating image for seed 6203 (3/441) ...
# Generating image for seed 6204 (4/441) ...
# Generating image for seed 6205 (5/441) ...
# Generating image for seed 6206 (6/441) ...
# Generating image for seed 6207 (7/441) ...
# Generating image for seed 6208 (8/441) ...
# Generating image for seed 6209 (9/441) ...
# Generating image for seed 6210 (10/441) ...
# Generating image for seed 6211 (11/441) ...
# Generating image for seed 6212 (12/441) ...
# Generating image for seed 6213 (13/441) ...
# ...

# %%
# !zip -r '/content/file.zip' '/content/stylegan2/results/00001-generate-images'
# Out:
#   adding: content/stylegan2/results/00001-generate-images/ (stored 0%)
#   adding: content/stylegan2/results/00001-generate-images/seed6405.png (deflated 0%)
#   adding: content/stylegan2/results/00001-generate-images/seed6522.png (deflated 0%)
#   adding: content/stylegan2/results/00001-generate-images/run.txt (deflated 32%)
#   adding: content/stylegan2/results/00001-generate-images/seed6444.png (deflated 0%)
#   adding: content/stylegan2/results/00001-generate-images/seed6315.png (deflated 0%)
#   adding: content/stylegan2/results/00001-generate-images/seed6392.png (deflated 0%)
#   adding: content/stylegan2/results/00001-generate-images/seed6225.png (deflated 0%)
#   adding: content/stylegan2/results/00001-generate-images/seed6398.png (deflated 0%)
#   adding: content/stylegan2/results/00001-generate-images/seed6505.png (deflated 0%)
#   adding: content/stylegan2/results/00001-generate-images/seed6604.png (deflated 0%)
# ...

# %%
# !zip -r '/content/animals.zip' '/content/stylegan2/results/00002-generate-images'
# Out:
#   adding: content/stylegan2/results/00002-generate-images/ (stored 0%)
#   adding: content/stylegan2/results/00002-generate-images/seed6405.png (deflated 0%)
#   adding: content/stylegan2/results/00002-generate-images/seed6522.png (deflated 1%)
#   adding: content/stylegan2/results/00002-generate-images/run.txt (deflated 32%)
#   adding: content/stylegan2/results/00002-generate-images/seed6444.png (deflated 0%)
#   adding: content/stylegan2/results/00002-generate-images/seed6315.png (deflated 0%)
#   adding: content/stylegan2/results/00002-generate-images/seed6392.png (deflated 0%)
#   adding: content/stylegan2/results/00002-generate-images/seed6225.png (deflated 1%)
#   adding: content/stylegan2/results/00002-generate-images/seed6398.png (deflated 1%)
#   adding: content/stylegan2/results/00002-generate-images/seed6505.png (deflated 0%)
#   adding: content/stylegan2/results/00002-generate-images/seed6604.png (deflated 0%)
# ...
